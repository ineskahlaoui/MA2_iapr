# %% [markdown]
# # [IAPR][iapr]: Lab 3 ‒  Classification
#
#
# **Group ID:** 6
#
# **Author 1 (sciper):** Marc Nicolas Domenjoz (295752)
# **Author 2 (sciper):** Thibault Jean-Baptiste Golaz (291348)
# **Author 3 (sciper):** Inès Kahlaoui (310587)
#
# **Release date:** 19.04.2023
# **Due date:** 05.05.2023
#
#
# ## Important notes
#
# The lab assignments are designed to teach practical implementation of the topics presented during class well as
# preparation for the final project, which is a practical project which ties together the topics of the course.
#
# As such, in the lab assignments/final project, unless otherwise specified, you may, if you choose, use external
# functions from image processing/ML libraries like opencv and sklearn as long as there is sufficient explanation
# in the lab report. For example, you do not need to implement your own edge detector, etc.
#
# **! Before handling back the notebook <font color='red'> rerun </font>the notebook from scratch !**
# `Kernel` > `Restart & Run All`
#
# We will not rerun the notebook for you.
#
#
# [iapr]: https://github.com/LTS5/iapr

# %% [markdown]
# --
# ## 0. Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# In this lab, we will use PyTorch. If you are not familiar with this library, [here](https://pytorch.org/tutorials/beginner/blitz/tensor_tutorial.html) is a quick tutorial of the basics.

# %%
import platform
print(platform.system())
if platform.system() == "Darwin":
    # %pip install torch==1.8.1 torchvision==0.9.1
else:
    # %pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Darwin
# Requirement already satisfied: torch==1.8.1 in /Users/ines/opt/miniconda3/lib/python3.8/site-packages (1.8.1)
# Requirement already satisfied: torchvision==0.9.1 in /Users/ines/opt/miniconda3/lib/python3.8/site-packages (0.9.1)
# Requirement already satisfied: numpy in /Users/ines/opt/miniconda3/lib/python3.8/site-packages (from torch==1.8.1) (1.23.5)
# Requirement already satisfied: typing-extensions in /Users/ines/opt/miniconda3/lib/python3.8/site-packages (from torch==1.8.1) (4.5.0)
# Requirement already satisfied: pillow>=4.1.1 in /Users/ines/opt/miniconda3/lib/python3.8/site-packages (from torchvision==0.9.1) (8.2.0)
#
# [notice] A new release of pip is available: 23.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import tarfile
import os

data_base_path = os.path.join(os.pardir, 'data')
data_folder = 'lab-03-data'
tar_path = os.path.join(data_base_path, data_folder + '.tar.gz')
with tarfile.open(tar_path, mode='r:gz') as tar:
    tar.extractall(path=data_base_path)

# %% [markdown]
# ---
# ## Part 1 - Out-of-Distribution detection in colorectal cancer histology (12 points)
#
# Colorectal cancer is one of the most widespread cancers for men and women. Diagnosis complemented with prognostic and predictive biomarker information is essential for patient monitoring and applying personalized treatments. A critical marker is the tumor/stroma ratio in unhealthy tissues sampled from the colon. The higher the ratio, the more invasive the cancer is. The degree of invasion is tightly linked to patient survial probability.
#
# To measure the ratio, a pathologist needs to analyze the unhealthy tissue under a microscope and estimate it from a look. As the number of samples to analyze is huge and estimations are only sometimes precise, automatic recognition of the different tissue types in histological images has become essential. Such an automatic process requires the development of a multi-class classifier to identify the numerous tissues. As shown below, they are usually 8 tissue types to categorize: TUMOR, STROMA, LYMPHO (lymphocytes), MUCOSA, COMPLEX (complex stroma), DEBRIS, ADIPOSE and EMPTY (background).
#
# <br />
# <br />
# <figure>
#     <img src="../data/lab-03-data/part1/kather16.svg" width="1100">
#     <center>
#     <figcaption>Fig1: Collection of tissue types in colorectal cancer histology (Kather-16)</figcaption>
#     </center>
# </figure>
# <br />
# <br />
#
#
# Up to this day, state-of-the-art methods use deep-learning-based supervised learning methods. A downfall of such an approach is the necessity to access a well-annotated training dataset. In histology, annotating data is difficult. It is time-consuming and requires the expertise of pathologists. Moreover, the annotator must label every tissue type while only two (TUMOR and STROMA) are interesting.
#
#
# Consequently, we propose another approach. In order to make the annotation task less tedious, we ask the annotator to label only the tissues of interest and dump the others. Then, we must train a binary classifier to automatically recognize these tissues at test time. In this part, you will implement the proposed approach.

# %% [markdown]
# ### 1.1 Binary classifier with Mahalanobis distance (3 points)
#
# Based on the abovementioned process, your task is to build a model that recognizes TUMOR (Label 0) and STROMA (Label 1) tissue types. Your model will be supervised by a training dataset containing TUMOR and STROMA annotations; note that all other tissues have been dropped.
# We will not ask you to train a deep-learning-based binary classifier from scratch. Instead, we provide excellent features (descriptors) of the images we extracted from a visual foundation model. (Note: As the nature of the foundation model is not part of this lecture, feel free to ask TAs if you are curious).
#
# Run the cell below to extract the provided train and test dataset. Each image is represented by a 768-d feature vector extracted from a visual foundation model. The train and test datasets contain feature vectors of 878 and 186 images respectively.

# %%
import torch 
from sklearn.covariance import LedoitWolf
import numpy as np

# Label mapping
label_to_classname = {0 : "TUMOR", 1 : "STROMA"}

# Train features and labels
train_features = torch.load(os.path.join(data_base_path, data_folder, "part1/k16_train_features.pth"))
train_labels = torch.load(os.path.join(data_base_path, data_folder, "part1/k16_train_labels.pth"))

# Test features and labels
test_features = torch.load(os.path.join(data_base_path, data_folder, "part1/k16_test_features.pth"))
test_labels = torch.load(os.path.join(data_base_path, data_folder, "part1/k16_test_labels.pth"))

train_features.shape
# Out:
# torch.Size([878, 768])

# %% [markdown]
# **Task 1 (2.5 points)** Based on the training features (```train_features```) and training labels (```train_labels```), classify the test features (```test_features```) using minimum Mahalanobis distance.
#
# *Note:* You are not allowed to use any prebuilt Mahalanobis distance function. Additionally, ```torch.cov``` is not defined to compute the covariance matrix. You can use ```sklearn.covariance.LedoitWolf``` instead.

# %%
from sklearn.covariance import LedoitWolf
from sklearn.metrics import accuracy_score

def mahalanobis_distance(x, y, inv_cov_matrix):
    diff = x - y
    return np.sqrt(diff.dot(inv_cov_matrix).dot(diff.T))

def min_mahalanobis_distance(train_features, train_labels, test_features, ood=False):
    classes = np.unique(train_labels)
    n_classes = len(classes)
    means = []
    cov_matrices = []
    for c in classes:
        Xc = train_features[train_labels == c]
        means.append(np.mean(Xc, axis=0))
        cov_matrices.append(LedoitWolf().fit(Xc).covariance_)
    predictions = np.zeros(len(test_features))
    min_dist_maha = np.zeros(len(test_features))
    for i, x in enumerate(test_features):
        min_dist = None
        min_class = None
        for j in range(n_classes):
            try:
                inv_cov_matrix = np.linalg.inv(cov_matrices[j])
                dist = mahalanobis_distance(x, means[j], inv_cov_matrix)
                if min_dist is None or dist < min_dist:
                    min_dist = dist
                    min_class = classes[j]
            except np.linalg.LinAlgError:
                continue
        predictions[i] = min_class
        min_dist_maha[i] = min_dist
    if ood is False:
        return predictions
    else: 
        return min_dist_maha, predictions

# %% [markdown]
# **Task 2 (0.5 points)** Compute the accuracy of your predictions with the test labels (```test_labels```).

# %%
predictions = min_mahalanobis_distance(train_features.cpu().detach().numpy(), train_labels, test_features.cpu().detach().numpy())
accuracy = accuracy_score(test_labels, predictions)

print(accuracy)
# Out:
# 0.978494623655914

# %% [markdown]
# ### 1.2 Out-of-Distribution detection with Mahalanobis distance (3 points)
#
# You will note that the test you run above is not really realistic. Like the training set, it contains only the TUMOR and STROMA tissue types. Nevertheless, at test time, the other tissues (Label -1) are also present and cannot be filtered by hand. Moreover, they cannot be recognized by the model as they are out of the training distribution (It is the consequence of the laziness of the annotators ;)). For this reason, it is essential to filter them out. This task is called Out-of-Distribution (OoD) detection.
#
# A simple way to do OoD detection is to compute for every test example an OoD-ness score which should be low for In-Distribution (ID) examples and high for OoDs. Then we define a threshold from which every example with an OoD-ness lying above is discarded, and those lying below are forwarded to the model for prediction. An example of OoD-ness score is the minimum Mahalanobis distance.
#
# Run the cell below to load a new test set containing OoD examples. It has 186 ID and 558 OoD examples.

# %%
label_to_classname_w_ood = {0 : "TUMOR", 1 : "STROMA", -1 : "OoD"}

# Test features and labels with OoD tissues
test_features_w_ood = torch.load(os.path.join(data_base_path, data_folder, "part1/k16_test2_features.pth"))
test_labels_w_ood = torch.load(os.path.join(data_base_path, data_folder,"part1/k16_test2_labels.pth"))

test_features_w_ood.shape
# Out:
# torch.Size([744, 768])

# %% [markdown]
# **Task 1 (0.5 point)** Why do you think the minimum Mahalanobis distance is a good OoD-ness score?

# %% [markdown]
# **Answer:** The Mahalanobis distance is a metric that considers the covariance of the data, which makes it sensitive to changes in the data distribution. The minimum Mahalanobis distance measures how far a sample is from the mean of the nearest class, which makes it a good measure of OoD-ness because it identifies samples that are significantly different from the data used for training.

# %% [markdown]
# **Task 2 (0.5 point)** Compute the minimum Mahalanobis distance for every test examples in ```test_features_w_ood``` with respect to the training features (```train_features```).

# %%
min_dist, predictions = min_mahalanobis_distance(train_features.cpu().detach().numpy()
                                    , train_labels, test_features_w_ood.cpu().detach().numpy(), ood=True)

# %% [markdown]
# **Task 3 (0.5 point)** Plot a histogram to show the difference between the Mahalanobis distance of TUMOR, STROMA and OoD tissue types and comment on what you observe.

# %%
import matplotlib.pyplot as plt
plt.hist(min_dist)
# Out:
# (array([ 40., 162., 159., 106.,  73.,  14.,  15.,  31.,  84.,  60.]),
#  array([22.10648346, 28.6597641 , 35.21304474, 41.76632538, 48.31960602,
#         54.87288666, 61.4261673 , 67.97944794, 74.53272858, 81.08600922,
#         87.63928986]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# **Observations:** The histogram doesn't look as expected, when we look at it we could think that a good threshold would be 60. But with this value we would get a high amount of OOD not filtered which is not what we want here

# %% [markdown]
# **Task 4 (1 point)** Find a threshold on the Mahalanobis distance such that 95% of the OoD examples are filtered out. How much TUMOR and STROMA have also been filtered out?

# %%
#thresholding, I took 35 as a threshold to be able to have a number near 558 
min_dist_wo_ood = (min_dist < 35) * min_dist
min_zero = (min_dist_wo_ood == 0)
total_ood = sum(min_zero)
print("Total OOD found:", total_ood)

counter_tumor = 0
counter_stroma = 0
for i in range(len(test_labels_w_ood)):
    if(min_dist_wo_ood[i] == 0 and test_labels_w_ood[i] == 1): 
        counter_stroma = counter_stroma + 1
    if(min_dist_wo_ood[i] == 0 and test_labels_w_ood[i] == 0):
        counter_tumor = counter_tumor + 1
        
print("amount of tumor filtered:", counter_tumor)
print("amount of stroma filtered:", counter_stroma)
# Out:
# Total OOD found: 549
# amount of tumor filtered: 31
# amount of stroma filtered: 51

# %% [markdown]
# **Task 5 (0.5 point)** Assign prediction -1 to filtered out examples and compute the average class-wise accuracy of your prediction with test labels (```test_labels_w_ood```). Is it satisfactory?

# %%
#replacing the ood by label -1
for i in range(len(min_dist_wo_ood)):
    if(min_dist_wo_ood[i] == 0):
        predictions[i] = -1

accuracy = accuracy_score(test_labels_w_ood, predictions)
print(accuracy)
# Out:
# 0.7661290322580645

# %% [markdown]
# ### 1.3 Out-of-distribution detection with k-NN classifier (6 points)
#
# The visual foundation models are known to be very good k-NN classifiers. It motivates us to implement a k-NN classifier to recognize TUMOR and STROMA. Moreover, k-NN distance is a good OoD-ness score and suits our task.
#
# **Task 1 (2 points)** Based on the training features (```train_features```) and training labels (```train_labels```), classify the test features (```test_features```) using a k-NN classifier. Then report the accuracy of your predictions with the test labels (```test_labels```).
#
# *Note:* The choice of `k` is up to you.

# %%
### Task 1
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# create k-NN classifier with k=3
knn = KNeighborsClassifier(n_neighbors=5)

# train the classifier using the training data
knn.fit(train_features, train_labels)

# make predictions on the test data
predicted_labels = knn.predict(test_features)
#print(knn.predict(test_features))

# calculate accuracy of predictions
accuracy = accuracy_score(test_labels, predicted_labels)

print("The accuracy is:", accuracy)
# Out:
# The accuracy is: 0.9946236559139785
# /Users/ines/opt/miniconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %% [markdown]
# **Task 2 (2 points)** Perform OoD detection on the test features (```test_features_w_ood```) using a k-NN distance based OoD-ness score. Find a threshold on your OoD-ness score such that 95% of the OoD examples are filtered out. How much TUMOR and STROMA have also been filtered out? Finally, assign prediction -1 to filter out examples and compute the average class-wise accuracy of your prediction with test labels (```test_labels_w_ood```).
#
# *Note:* The OoD-ness is based on the distance to the k-nearest neighbors. The formulation is up to you. You have to justify your choice.

# %%
### Task 2
import numpy as np
from sklearn.neighbors import NearestNeighbors

#calculate k-NN distances for test data
k = 5  #number of neighbors to use
nbrs = NearestNeighbors(n_neighbors=k, algorithm='ball_tree').fit(train_features)
distances, indices = nbrs.kneighbors(test_features_w_ood)
predicted_labels_w_ood = np.zeros(len(test_features))

#calculate mean distance to k-NNs for each test sample
mean_distances = np.mean(distances, axis=1)

#filter OoD samples and assign prediction -1
min_dist_wo_ood = (mean_distances < 47) * mean_distances
min_zero = (min_dist_wo_ood == 0)
total_ood = sum(min_zero)
print("Total OOD found:", total_ood)

counter_tumor = 0
counter_stroma = 0
for i in range(len(test_labels_w_ood)):
    if(min_dist_wo_ood[i] == 0 and test_labels_w_ood[i] == 1): 
        counter_stroma = counter_stroma + 1
    if(min_dist_wo_ood[i] == 0 and test_labels_w_ood[i] == 0):
        counter_tumor = counter_tumor + 1
        
print("amount of tumor filtered:", counter_tumor)
print("amount of stroma filtered:", counter_stroma)

#replacing the ood by label -1
for i in range(len(min_dist_wo_ood)):
    if(min_dist_wo_ood[i] == 0):
        predictions[i] = -1

accuracy = accuracy_score(test_labels_w_ood, predictions)
print("The accuracy is:", accuracy)
# Out:
# Total OOD found: 549
# amount of tumor filtered: 41
# amount of stroma filtered: 31
# The accuracy is: 0.7795698924731183

# %% [markdown]
# **Task 3 (1 point)** Is k-NN better than Mahalanobis distance ? Make an hypothesis for the reasons.

# %% [markdown]
# **Answer:** It's hard to definitively say whether k-NN is better than Mahalanobis distance because it depends on the specific use case and the nature of the data. And we can see on our accuracies that they are very similar, which make the decision even harder. However, k-NN is a simpler and more intuitive method, as it directly compares the test point to its k nearest neighbors in the training set. Mahalanobis distance needs the inverse covariance matrix, which can be computationally expensive and requires assumptions about the distribution of the data.

# %% [markdown]
# **Task 4 (1 point)** Do you think we can suggest the approach presented in this exercise to compute TUMOR/STROMA ratio automatically ? Justify your thoughs. If not, suggest at least two ideas to improve it.
#
# *Note:* Annotating all the training dataset is not an option.

# %% [markdown]
# **Answer:** I would not suggest the approach presented in this exercise to compute the TUMOR/STROMA ratio automatically, as the Mahalanobis distance is not directly related to this ratio. Mahalanobis distance outliers or anomalous data points.
#
# One idea to improve could be:
#
# Use unsupervised clustering, for example k-means to separate the image into regions based on the similarity of their features.
#
# Unfortunately I don't see another method that we could use to get better results without validation or annotation.

# %% [markdown]
# ---
#
# ## Part 2 (12 points)
# In this part, we aim to classify cervical cells resulting from Pap smear tests. To that end we'll be using a publicly available cell dataset: Sipakmed (https://www.cs.uoi.gr/~marina/sipakmed.html). The dataset is composed of 4049 images of isolated cells cropped from 966 cluster cell images of Pap smear slides. Each cell in the dataset has been categorized in either of the following categories:
#
#     - Superficial-Intermediate.
#     - Parabasal.
#     - Koilocytotic.
#     - Dysketarotic.
#     - Metaplastic.
# Your objective is to implement a classifier to automate the cell classification process. To ease your work we provide you with pre-computed embeddings for each images (`lab-03-data/part2/sipakmed_clean_embeddings.pth`). The embeddings are obtained from a pre-trained ResNet-50 (https://arxiv.org/pdf/1512.03385.pdf) and the corresponding images are also provided (`lab-03-data/part2/sipakmed_clean`). Note that you are free to discard the provided embeddings and work directy with the images.

# %% [markdown]
# ### 2.1 Dataset (4 points)
# Your first task is prepare the dataset such that it can be used to train your model. For that purpose we prepared the skeleton of the class `Sipakmed` that inherits from the class `Dataset` of PyTorch. Read the documentation (https://pytorch.org/tutorials/beginner/basics/data_tutorial.html#creating-a-custom-dataset-for-your-files) and complete the missing parts.

# %%
import torch
import numpy as np
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from PIL import Image
import os
from torch import nn
from collections import OrderedDict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import math

# %%
# Load the features
features_path = '../data/lab-03-data/part2/sipakmed_clean_embeddings.pth'

# %%
class Sipakmed(Dataset):
    phase_dict = {
            'train': {'start': 0.0, 'stop': 0.5},
            'val': {'start': 0.5, 'stop': 0.75},
            'test': {'start': 0.75, 'stop': 1.0}
    }
    label_dict = {
        'im_Superficial-Intermediate': 0,
        'im_Parabasal': 1, 
        'im_Metaplastic': 2,
        'im_Koilocytotic': 3,
        'im_Dyskeratotic': 4
    }
    
    def __init__(self, features_path, phase):

        super(Sipakmed, self).__init__()
        # Store class attributes
        self.phase = phase
        
        # Collect the dataimport torch
        import torch.nn.functional as F
        import numpy as np
        self.raw_data = torch.load(features_path)
        self.features, self.labels, self.paths = self.collect_data()
        
    def collect_data(self):
        # Iterate over the dirs/classes
        features, labels, paths = [], [], []
        for dir_name, dir_dict in self.raw_data.items():
            # Get the paths and embeddings
            dir_paths, dir_embeddings = list(zip(*[(k, v) for k, v in dir_dict.items()]))
            
            # Split
            n = len(dir_paths)
            np.random.seed(42)
            permutations = np.random.permutation(n)
            dir_paths = np.array(dir_paths)[permutations]
            dir_embeddings = torch.stack(dir_embeddings)[permutations]
            n_start = int(n * self.phase_dict[self.phase]['start'])
            n_stop = int(n * self.phase_dict[self.phase]['stop'])
            dir_embeddings = dir_embeddings[n_start: n_stop]
            dir_paths = dir_paths[n_start: n_stop]
    
            # Store
            features.append(dir_embeddings)
            paths.append(dir_paths)
            dir_labels = torch.tensor([self.label_dict[p.split('/')[-2]] for p in dir_paths])
            labels.append(dir_labels)
            
        # Merge
        features = torch.cat(features)
        labels = torch.cat(labels)
        paths = np.concatenate(paths)
        return features, labels, paths
            
        
    def __len__(self,):
        """
        Returns the number of samples in the dataset.
        """
        return len(self.labels)
    
    def __getitem__(self, index):
        """
        Returns the embedding, label, and image path of queried index.
        """
        embedding = self.features[index]
        label = self.labels[index]
        path = self.paths[index]
        
        return embedding, label, path

# %% [markdown]
# Once the implementation of `Sipakmed` completed, create 3 instances of the class (train/val/test) with the corresponding `phase` flag.

# %%
# Instantiate the datasets
train_dataset = Sipakmed(features_path = features_path, phase = 'train')
val_dataset = Sipakmed(features_path = features_path, phase = 'val')
test_dataset = Sipakmed(features_path = features_path, phase = 'test')

# %% [markdown]
# Now that your datasets are ready, use the class `DataLoader` from PyTorch to let it handle efficiently the batching, shuffling, etc. of your data.

# %%
# Instantiate the data loaders
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size = batch_size, shuffle = True)
val_loader = DataLoader(val_dataset, batch_size = batch_size, shuffle = False)
test_loader = DataLoader(test_dataset,batch_size = batch_size, shuffle = False)

# %% [markdown]
# Get to know your data. Plot a few example images for each class of your dataset.

# %%
# Visualize some training example
base_path = '../data/lab-03-data/part2/'
class_labels = [0,1,2,3,4] * 2

while(class_labels):
    train_embedding, train_label, train_img = next(iter(train_loader))
    label = train_label[0]
    if (label in class_labels):
        class_labels.remove(label)
        img = np.asarray(Image.open(base_path + train_img[0]))
        plt.imshow(img)
        plt.title(f"Image with label: {label}")
        plt.show()

# %% [markdown]
# ### 2.2 Training (4 points)
# In this part your objective is to implement the required tools to train your model. The first thing you'll need is a a model which takes as input the pre-computed features and returns the corresponding class probabilities/logits.

# %%
# Implement the model
embedding_dim = train_dataset.features.shape[1]

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(embedding_dim, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 5)
        self.relu = nn.ReLU()
        
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        out = self.relu(out)
        out = self.fc3(out)
        return out
    

device = 'cuda' if torch.cuda.is_available() else 'cpu'
#definition of a model
model = Net().to(device)

# %% [markdown]
# The optimizer will keep track of your model's parameters, gradients, etc (https://pytorch.org/docs/stable/optim.html). It is responsible to update your model's parameters after each forward pass using the backpropagation algorithm.

# %%
# Set the optimizer
from torch.optim import Adam
optimizer = Adam(model.parameters(), lr = 1e-3)

# %%
# Set the loss
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# Implement a function that takes as input the model's output and the corresponding labels and returns the perçentage of correct predictions.

# %%
def accuracy(outputs, labels):
    """
    Computes the accuracy of predictions based on the model outputs (NxK: N samples, K classes) 
    and the labels (N: N samples).
    """
    _, predicted = torch.max(outputs, 1)
    correct = (predicted == labels).sum().item()
    accuracy = correct / labels.size(0)
    return accuracy

# %% [markdown]
# Implement a funtion `train` that forwards the complete training set through your model (= 1 epoch) and updates its parameters after each forward pass. To keep track of the training process make sure to at least return the accuracy of the model and the average loss it incurred through the current epoch.

# %%
def train(model, optimizer, criterion, loader):
    # Set the model in train mode
    ### YOUR CODE
    
    # Iterate over the batches
    full_outputs = []
    full_labels = []
    losses = []
    for batch in loader:
        # Get the embeddings, labels and paths 
        embeddings, labels, paths = batch
        
        # Feed the embeddings to the model
        outputs = model(embeddings)

        # Compute cross entropy loss
        loss = criterion(outputs, labels)
        
        # Reset the gradients
        optimizer.zero_grad()
        
        # Backpropagate
        loss.backward()

        # Update the parameters
        optimizer.step()
        
        # Store the outputs, labels and loss
        full_outputs.append(outputs)
        full_labels.append(labels)
        losses.append(loss)
    
    # Concat
    full_outputs = torch.cat(full_outputs).cpu()
    full_labels = torch.cat(full_labels).cpu()
    losses = torch.stack(losses).mean().cpu()
    
    # Compute the accuracy
    acc = accuracy(full_outputs, full_labels)
    
    return acc, full_outputs, full_labels, losses

# %% [markdown]
# Implement a funtion `validate` that forwards the complete validation or test set through your model and evaluates its predictions. To keep track of the training process make sure to at least return the accuracy of the model and the average loss it incurred through the current epoch.

# %%
@torch.no_grad()
def validate(model, criterion, loader):
    # Set the model in train mode
    ### YOUR CODE
    
    # Iterate over the batches
    full_outputs = []
    full_labels = []
    full_paths = []
    losses = []
    for batch in loader:
        # Get the embeddings, labels and paths
        embeddings, labels, paths = batch
        
        # Feed the embeddings to the model
        outputs = model(embeddings)

        # Compute cross entropy loss
        loss = criterion(outputs, labels)
        
        # Store the outputs, labels and loss
        full_outputs.append(outputs)
        full_labels.append(labels)
        full_paths.append(paths)
        losses.append(loss)
    
    # Concat
    full_outputs = torch.cat(full_outputs).cpu()
    full_labels = torch.cat(full_labels).cpu()
    losses = torch.stack(losses).mean().cpu()
    full_paths = np.concatenate(full_paths)
    
    # Compute the accuracy
    acc = accuracy(full_outputs, full_labels)
    
    return acc, full_outputs, full_labels, losses, full_paths

# %% [markdown]
# You should now be able to train you model. Alternate between training and validation steps to find and save the best model (best accuracy on the validation set).

# %%
# Main loop
epochs = 100
best_acc = 0
model_savepath = '../data'

for epoch in range(epochs):
    # Train
    train_acc, _, _, train_loss = train(model, optimizer, criterion, train_loader)

    # Evaluate
    val_acc, _, _, val_loss, _ = validate(model, criterion, val_loader)

    # Save the model
    if val_acc > best_acc:
        best_acc = val_acc
        torch.save(model.state_dict(), f'{model_savepath}/best_model.pth')

    print(f'Epoch {epoch+1} - Train accuracy: {train_acc:.4f}, Train loss: {train_loss:.4f}, Validation accuracy: {val_acc:.4f}, Validation loss: {val_loss:.4f}')

print(f'Best validation accuracy: {best_acc:.4f}')
# Out:
# Epoch 1 - Train accuracy: 0.8007, Train loss: 0.6611, Validation accuracy: 0.9150, Validation loss: 0.2753
# Epoch 2 - Train accuracy: 0.9466, Train loss: 0.1728, Validation accuracy: 0.9377, Validation loss: 0.1921
# Epoch 3 - Train accuracy: 0.9693, Train loss: 0.1022, Validation accuracy: 0.9358, Validation loss: 0.1900
# Epoch 4 - Train accuracy: 0.9817, Train loss: 0.0584, Validation accuracy: 0.9358, Validation loss: 0.1887
# Epoch 5 - Train accuracy: 0.9911, Train loss: 0.0382, Validation accuracy: 0.9377, Validation loss: 0.1825
# Epoch 6 - Train accuracy: 0.9955, Train loss: 0.0264, Validation accuracy: 0.9387, Validation loss: 0.2147
# Epoch 7 - Train accuracy: 0.9980, Train loss: 0.0157, Validation accuracy: 0.9417, Validation loss: 0.1841
# Epoch 8 - Train accuracy: 0.9995, Train loss: 0.0117, Validation accuracy: 0.9397, Validation loss: 0.1957
# Epoch 9 - Train accuracy: 1.0000, Train loss: 0.0069, Validation accuracy: 0.9417, Validation loss: 0.1909
# Epoch 10 - Train accuracy: 1.0000, Train loss: 0.0048, Validation accuracy: 0.9407, Validation loss: 0.1955
# Epoch 11 - Train accuracy: 1.0000, Train loss: 0.0037, Validation accuracy: 0.9437, Validation loss: 0.2030
# Epoch 12 - Train accuracy: 1.0000, Train loss: 0.0030, Validation accuracy: 0.9397, Validation loss: 0.2083
# Epoch 13 - Train accuracy: 1.0000, Train loss: 0.0026, Validation accuracy: 0.9417, Validation loss: 0.2127
# Epoch 14 - Train accuracy: 1.0000, Train loss: 0.0021, Validation accuracy: 0.9417, Validation loss: 0.2159
# Epoch 15 - Train accuracy: 1.0000, Train loss: 0.0017, Validation accuracy: 0.9447, Validation loss: 0.2190
# Epoch 16 - Train accuracy: 1.0000, Train loss: 0.0014, Validation accuracy: 0.9407, Validation loss: 0.2203
# Epoch 17 - Train accuracy: 1.0000, Train loss: 0.0012, Validation accuracy: 0.9397, Validation loss: 0.2254
# Epoch 18 - Train accuracy: 1.0000, Train loss: 0.0011, Validation accuracy: 0.9407, Validation loss: 0.2278
# Epoch 19 - Train accuracy: 1.0000, Train loss: 0.0009, Validation accuracy: 0.9427, Validation loss: 0.2354
# Epoch 20 - Train accuracy: 1.0000, Train loss: 0.0008, Validation accuracy: 0.9427, Validation loss: 0.2341
# Epoch 21 - Train accuracy: 1.0000, Train loss: 0.0008, Validation accuracy: 0.9407, Validation loss: 0.2386
# Epoch 22 - Train accuracy: 1.0000, Train loss: 0.0006, Validation accuracy: 0.9407, Validation loss: 0.2423
# Epoch 23 - Train accuracy: 1.0000, Train loss: 0.0005, Validation accuracy: 0.9387, Validation loss: 0.2413
# Epoch 24 - Train accuracy: 1.0000, Train loss: 0.0005, Validation accuracy: 0.9397, Validation loss: 0.2460
# Epoch 25 - Train accuracy: 1.0000, Train loss: 0.0004, Validation accuracy: 0.9417, Validation loss: 0.2493
# Epoch 26 - Train accuracy: 1.0000, Train loss: 0.0004, Validation accuracy: 0.9407, Validation loss: 0.2506
# Epoch 27 - Train accuracy: 1.0000, Train loss: 0.0004, Validation accuracy: 0.9407, Validation loss: 0.2521
# Epoch 28 - Train accuracy: 1.0000, Train loss: 0.0003, Validation accuracy: 0.9427, Validation loss: 0.2544
# Epoch 29 - Train accuracy: 1.0000, Train loss: 0.0003, Validation accuracy: 0.9407, Validation loss: 0.2557
# Epoch 30 - Train accuracy: 1.0000, Train loss: 0.0003, Validation accuracy: 0.9437, Validation loss: 0.2587
# Epoch 31 - Train accuracy: 1.0000, Train loss: 0.0003, Validation accuracy: 0.9407, Validation loss: 0.2594
# Epoch 32 - Train accuracy: 1.0000, Train loss: 0.0003, Validation accuracy: 0.9407, Validation loss: 0.2615
# Epoch 33 - Train accuracy: 1.0000, Train loss: 0.0002, Validation accuracy: 0.9427, Validation loss: 0.2630
# Epoch 34 - Train accuracy: 1.0000, Train loss: 0.0002, Validation accuracy: 0.9417, Validation loss: 0.2646
# Epoch 35 - Train accuracy: 1.0000, Train loss: 0.0002, Validation accuracy: 0.9417, Validation loss: 0.2668
# Epoch 36 - Train accuracy: 1.0000, Train loss: 0.0002, Validation accuracy: 0.9427, Validation loss: 0.2677
# Epoch 37 - Train accuracy: 1.0000, Train loss: 0.0002, Validation accuracy: 0.9407, Validation loss: 0.2703
# Epoch 38 - Train accuracy: 1.0000, Train loss: 0.0002, Validation accuracy: 0.9407, Validation loss: 0.2723
# Epoch 39 - Train accuracy: 1.0000, Train loss: 0.0002, Validation accuracy: 0.9407, Validation loss: 0.2726
# Epoch 40 - Train accuracy: 1.0000, Train loss: 0.0001, Validation accuracy: 0.9407, Validation loss: 0.2767
# Epoch 41 - Train accuracy: 1.0000, Train loss: 0.0001, Validation accuracy: 0.9427, Validation loss: 0.2763
# Epoch 42 - Train accuracy: 1.0000, Train loss: 0.0001, Validation accuracy: 0.9407, Validation loss: 0.2788
# Epoch 43 - Train accuracy: 1.0000, Train loss: 0.0001, Validation accuracy: 0.9427, Validation loss: 0.2792
# Epoch 44 - Train accuracy: 1.0000, Train loss: 0.0001, Validation accuracy: 0.9427, Validation loss: 0.2810
# Epoch 45 - Train accuracy: 1.0000, Train loss: 0.0001, Validation accuracy: 0.9427, Validation loss: 0.2831
# Epoch 46 - Train accuracy: 1.0000, Train loss: 0.0001, Validation accuracy: 0.9407, Validation loss: 0.2839
# Epoch 47 - Train accuracy: 1.0000, Train loss: 0.0001, Validation accuracy: 0.9387, Validation loss: 0.2857
# Epoch 48 - Train accuracy: 1.0000, Train loss: 0.0001, Validation accuracy: 0.9427, Validation loss: 0.2876
# Epoch 49 - Train accuracy: 1.0000, Train loss: 0.0001, Validation accuracy: 0.9407, Validation loss: 0.2885
# Epoch 50 - Train accuracy: 1.0000, Train loss: 0.0001, Validation accuracy: 0.9387, Validation loss: 0.2899
# Epoch 51 - Train accuracy: 1.0000, Train loss: 0.0001, Validation accuracy: 0.9397, Validation loss: 0.2908
# Epoch 52 - Train accuracy: 1.0000, Train loss: 0.0001, Validation accuracy: 0.9417, Validation loss: 0.2917
# Epoch 53 - Train accuracy: 1.0000, Train loss: 0.0001, Validation accuracy: 0.9407, Validation loss: 0.2936
# Epoch 54 - Train accuracy: 1.0000, Train loss: 0.0001, Validation accuracy: 0.9407, Validation loss: 0.2956
# Epoch 55 - Train accuracy: 1.0000, Train loss: 0.0001, Validation accuracy: 0.9417, Validation loss: 0.2969
# Epoch 56 - Train accuracy: 1.0000, Train loss: 0.0001, Validation accuracy: 0.9407, Validation loss: 0.2968
# Epoch 57 - Train accuracy: 1.0000, Train loss: 0.0001, Validation accuracy: 0.9387, Validation loss: 0.2990
# Epoch 58 - Train accuracy: 1.0000, Train loss: 0.0001, Validation accuracy: 0.9417, Validation loss: 0.3004
# Epoch 59 - Train accuracy: 1.0000, Train loss: 0.0001, Validation accuracy: 0.9407, Validation loss: 0.3001
# Epoch 60 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3016
# Epoch 61 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9397, Validation loss: 0.3041
# Epoch 62 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9397, Validation loss: 0.3056
# Epoch 63 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9387, Validation loss: 0.3067
# Epoch 64 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3083
# Epoch 65 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9397, Validation loss: 0.3093
# Epoch 66 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3103
# Epoch 67 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3113
# Epoch 68 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9397, Validation loss: 0.3123
# Epoch 69 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3135
# Epoch 70 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3146
# Epoch 71 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3156
# Epoch 72 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3162
# Epoch 73 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3177
# Epoch 74 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9397, Validation loss: 0.3194
# Epoch 75 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3206
# Epoch 76 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9397, Validation loss: 0.3217
# Epoch 77 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9397, Validation loss: 0.3222
# Epoch 78 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3235
# Epoch 79 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3250
# Epoch 80 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9397, Validation loss: 0.3264
# Epoch 81 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9397, Validation loss: 0.3280
# Epoch 82 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3286
# Epoch 83 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3296
# Epoch 84 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3301
# Epoch 85 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3315
# Epoch 86 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3330
# Epoch 87 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3339
# Epoch 88 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3350
# Epoch 89 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9397, Validation loss: 0.3355
# Epoch 90 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3368
# Epoch 91 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9397, Validation loss: 0.3375
# Epoch 92 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9397, Validation loss: 0.3388
# Epoch 93 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9397, Validation loss: 0.3382
# Epoch 94 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3399
# Epoch 95 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3420
# Epoch 96 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3426
# Epoch 97 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9397, Validation loss: 0.3438
# Epoch 98 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3449
# Epoch 99 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9397, Validation loss: 0.3463
# Epoch 100 - Train accuracy: 1.0000, Train loss: 0.0000, Validation accuracy: 0.9407, Validation loss: 0.3471
# Best validation accuracy: 0.9447

# %% [markdown]
# ### 2.3 Evaluation (4 points)
# Re-load the best model and evaluate its predictions on the test set.

# %%
# Re-load the best model
model.load_state_dict(torch.load(f'{model_savepath}/best_model.pth'))

# Evaluate
test_acc, test_outputs, test_labels, test_losses, test_paths = validate(model, criterion, test_loader)

print(f'Test accuracy: {test_acc:.4f}, Test loss: {test_losses:.4f}')
# Out:
# Test accuracy: 0.9438, Test loss: 0.2428

# %% [markdown]
# A useful tool to analyze your model's performance on the different classes is the confusion matrix (https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html). Computes its entries for your model and the test set.

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns

test_preds = test_outputs.argmax(axis=1)

cm = confusion_matrix(test_labels, test_preds)
sns.heatmap(cm, annot=True, fmt='d', cmap='BuPu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Alternatively it can be useful to plot the problematic samples as well as the predicted and ground truth classes. Can you do so?

# %%
# Get the indices of the misclassified samples
# misclassified_idx = [i for i in range(len(test_labels)) if test_labels[i] != pred_labels[i]]

misc_idx = np.argwhere(test_labels != test_preds)
misc_paths = test_paths[misc_idx]
misc_labels = test_labels[misc_idx]
misc_preds = test_preds[misc_idx]


# Plot the misclassified samples
fig, axes = plt.subplots(10, 10, figsize = (25 , 25))
plt.suptitle("Misclassification of images (True VS Predicted labels)")
n_plots = len(misc_idx[0])
print(n_plots)

for i in range(0,200, 10):
    for j in range(10):
        if (i + j) < n_plots:
            path = '../data/lab-03-data/part2/' + str(misc_paths[0][i+j])
            label = int(misc_labels[0][i + j])
            pred = int(misc_preds[0][i + j])
            
            axes[int(i/10), j].imshow(Image.open(path, "r"))
            axes[int(i/10), j].set_title("True label = "+ str(label) + "\n Predicted label = "+ str(pred))
        else:
            break
        
[ax.axis('off') for ax in axes.ravel()]

plt.show()
# Out:
# 57
